# %%
import pandas as pd
import numpy as np
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Analysis and Prediction on Customer Purchase Behaviour**

# %% [markdown]
# ##1-.Dataset Maestro Producto

# %% [markdown]
# ###1.1-.Descripción del Conjunto de Datos:
#
#
#
# 1.   NUM: identificador del registro
#
# 1.   COD_PRODUCTO : Código del producto
#
# 1.   EAN: Código de barras de cada producto
#
# 1.   PRODUCT_CATEGORY: Categoría del producto
#
# 1.   SLUG: Nombre del producto
#
# 1.   LEGAL_NAME: Nombre legal(comercial) del producto
#
# 2.   BRAND: Nombre de la marca
#
# 2.   ORIGIN: País de origen del producto
#
# 2.   SUPPLIER: Nombre del proveedor
#
# 2.   PRICE: Precio unitario
#
# 2.   UNIT:Peso unitario del producto (litros, gramos,kg)

# %%
df_productos= pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/MAESTRO_PRODUCTOS.csv', sep=';', encoding='latin1')

# %%
display(df_productos.head(8))
# Out:
#    NUM  COD_PRODUCTO            EAN           PRODUCT_CATEGORY  \
# 0   88         17147  8480000171474  Aceite, especias y salsas
# 1   89         37408  8480000374080  Aceite, especias y salsas
# 2   90         34134  8480000341341  Aceite, especias y salsas
# 3   91         37405  8480000374059  Aceite, especias y salsas
# 4   92         22798  8480000227980  Aceite, especias y salsas
# 5   93         13406  8480000134066  Aceite, especias y salsas
# 6   94         13408  8480000134080  Aceite, especias y salsas
# 7   95         13407  8480000134073  Aceite, especias y salsas
#
#                                    SLUG               LEGAL_NAME      BRAND  \
# 0          sazonador-burritos-hacendado  Sazonador para Burritos  Hacendado
# 1  sazonador-pollo-carne-hacendado-bote    Sazonador Pollo/Carne  Hacendado
# 2        sazonador-pasta-hacendado-bote          Sazonador Pasta  Hacendado
# 3     sazonador-ensalada-hacendado-bote       Sazonador Ensalada  Hacendado
# ...

# %%
df_productos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4583 entries, 0 to 4582
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NUM               4583 non-null   int64
#  1   COD_PRODUCTO      4583 non-null   int64
#  2   EAN               4583 non-null   int64
#  3   PRODUCT_CATEGORY  4583 non-null   object
#  4   SLUG              4583 non-null   object
#  5   LEGAL_NAME        3059 non-null   object
#  6   BRAND             4098 non-null   object
#  7   ORIGIN            1518 non-null   object
#  8   SUPPLIER          3230 non-null   object
#  9   PRICE             4583 non-null   object
#  10  UNIT              4583 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 394.0+ KB

# %% [markdown]
# ###1.2.- Limpieza y análisis de cada variable en el conjunto de datos

# %%
df_productos.isnull().sum()
# Out:
# NUM                    0
# COD_PRODUCTO           0
# EAN                    0
# PRODUCT_CATEGORY       0
# SLUG                   0
# LEGAL_NAME          1524
# BRAND                485
# ORIGIN              3065
# SUPPLIER            1353
# PRICE                  0
# UNIT                   0
# dtype: int64

# %% [markdown]
# ####1.2.1 Análisis de las columnas LEGAL_NAME, ORIGIN, SUPPLIER, EAN Y NUM

# %% [markdown]
# Se decide eliminar las siguientes columnas ya que no serán variables en nuestro estudio.

# %%
df_productos = df_productos.drop(['LEGAL_NAME', 'ORIGIN', 'SUPPLIER','EAN','NUM','UNIT'], axis=1)

# %% [markdown]
# ####1.2.2 Análisis de Columna BRAND

# %% [markdown]
# Se visualiza que existe una poca cantidad relevante de valores nulos, por lo que se decide reemplazarlos a "Desconocido"

# %%
print(df_productos['BRAND'].isnull().sum())
# Out:
# 485

# %%
df_productos['BRAND'].fillna('Desconocido', inplace=True)

# %% [markdown]
# ####1.2.3 Análisis de la columna PRICE

# %% [markdown]
# La columna Price se cambia a dtype Float y se renombra a PRECIO_UNIDAD

# %%
#Convertimos la columna 'PRICE' a float para ayudarnos a los análisis posteriores.
df_productos['PRICE'] = df_productos['PRICE'].str.replace(',', '.').astype(float)

# %%
#Renombro la columna PRICE a 'PRECIO_UNIDAD'
df_productos = df_productos.rename(columns={'PRICE': 'PRECIO_UNIDAD'})

# %% [markdown]
# #### 1.2.4 Análisis de la columna PRODUCT_CATEGORY

# %%
print(df_productos['PRODUCT_CATEGORY'].dtype)
# Out:
# object

# %%
df_productos['PRODUCT_CATEGORY'] = df_productos['PRODUCT_CATEGORY'].astype('category')

# %%
df_productos.isnull().sum()
# Out:
# COD_PRODUCTO        0
# PRODUCT_CATEGORY    0
# SLUG                0
# BRAND               0
# PRECIO_UNIDAD       0
# dtype: int64

# %%
display(df_productos)
# Out:
#       COD_PRODUCTO           PRODUCT_CATEGORY  \
# 0            17147  Aceite, especias y salsas
# 1            37408  Aceite, especias y salsas
# 2            34134  Aceite, especias y salsas
# 3            37405  Aceite, especias y salsas
# 4            22798  Aceite, especias y salsas
# ...            ...                        ...
# 4578         39604                      Zumos
# 4579         39659                      Zumos
# 4580         39628                      Zumos
# 4581         39696                      Zumos
# 4582         39922                      Zumos
#
#                                                    SLUG      BRAND  \
# 0                          sazonador-burritos-hacendado  Hacendado
# 1                  sazonador-pollo-carne-hacendado-bote  Hacendado
# 2                        sazonador-pasta-hacendado-bote  Hacendado
# 3                     sazonador-ensalada-hacendado-bote  Hacendado
# 4                   sazonador-ras-hanout-hacendado-bote  Hacendado
# ...

# %%
#Guardamos los cambios realizados
df_productos.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_productos.pkl')

# %%
# Leer el archivo CSV y cargarlo en un DataFrame
df_productos = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_productos.pkl')

# %%
display(df_productos)
# Out:
#       COD_PRODUCTO           PRODUCT_CATEGORY  \
# 0            17147  Aceite, especias y salsas
# 1            37408  Aceite, especias y salsas
# 2            34134  Aceite, especias y salsas
# 3            37405  Aceite, especias y salsas
# 4            22798  Aceite, especias y salsas
# ...            ...                        ...
# 4578         39604                      Zumos
# 4579         39659                      Zumos
# 4580         39628                      Zumos
# 4581         39696                      Zumos
# 4582         39922                      Zumos
#
#                                                    SLUG      BRAND  \
# 0                          sazonador-burritos-hacendado  Hacendado
# 1                  sazonador-pollo-carne-hacendado-bote  Hacendado
# 2                        sazonador-pasta-hacendado-bote  Hacendado
# 3                     sazonador-ensalada-hacendado-bote  Hacendado
# 4                   sazonador-ras-hanout-hacendado-bote  Hacendado
# ...

# %% [markdown]
# ##2.- Dataset Maestro Promociones

# %% [markdown]
# ### 2.1-. Descripción del Conjunto de Datos
#
#
# 1.   COD_PROMOCION: Código de la promoción, codigo especifico por cada fecha
#
# 1.   FECHA_INICIO: Fecha en la que inicia la promoción
#
# 1.   FECHA_FIN: Fecha en la que finaliza la promoción
#
# 2.   DESC_PROMOCION -> Tipo de descuento de la promoción (10%,20%,30%..etc)
#
# 2.   TIPO_PROMOCION: codigo de la descripcion de DESC_PROMOCION
#
# *   1    [10% Descuento]
# *   2    [20% Descuento]
# *   3    [30% Descuento]
# *   4    [40% Descuento]
# *   5    [50% Descuento]
# *   6              [3x2]

# %%
df_promociones= pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/MAESTRO_PROMOCIONES.csv', sep=',', encoding='latin1')
# Mostramos la tabla con columnas
display(df_promociones.head(10))
# Out:
#    COD_PROMOCION  FECHA_INICIO  FECHA_FIN  TIPO_PROMOCION DESC_PROMOCION
# 0              1      20210101   20210108               1  10% Descuento
# 1              2      20210108   20210116               2  20% Descuento
# 2              3      20210101   20210108               3  30% Descuento
# 3              4      20210112   20210114               4  40% Descuento
# 4              5      20210104   20210105               5  50% Descuento
# 5              6      20210201   20210208               6            3x2
# 6              7      20210208   20210218               1  10% Descuento
# 7              8      20210301   20210304               2  20% Descuento
# 8              9      20210215   20210218               3  30% Descuento
# 9             10      20210224   20210228               4  40% Descuento

# %%
df_promociones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   COD_PROMOCION   70 non-null     int64
#  1   FECHA_INICIO    70 non-null     int64
#  2   FECHA_FIN       70 non-null     int64
#  3   TIPO_PROMOCION  70 non-null     int64
#  4   DESC_PROMOCION  70 non-null     object
# dtypes: int64(4), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# Verificamos que no existan valores nulos

# %%
print(df_promociones.isnull().sum())
# Out:
# COD_PROMOCION     0
# FECHA_INICIO      0
# FECHA_FIN         0
# TIPO_PROMOCION    0
# DESC_PROMOCION    0
# dtype: int64

# %% [markdown]
# ###2.2 Limpieza y análisis de cada variable en el conjunto de datos

# %% [markdown]
# ####2.2.1 Análisis de la columnas FECHA_INICIO y FECHA_FIN

# %%
#convertimos las columnas de cadena de texto en objetos de fecha y tiempo a las columnas FECHA_INICIO y FECHA_FIN
df_promociones['FECHA_INICIO'] = pd.to_datetime(df_promociones['FECHA_INICIO'], format='%Y%m%d')
df_promociones['FECHA_FIN'] = pd.to_datetime(df_promociones['FECHA_FIN'], format='%Y%m%d')

# %% [markdown]
# ####2.2.2 Análisis de la columna TIPO_PROMOCION

# %% [markdown]
# Verificamos la relación que tienen estas dos variables

# %%
print(df_promociones.groupby('TIPO_PROMOCION')['DESC_PROMOCION'].unique())
# Out:
# TIPO_PROMOCION
# 1    [10% Descuento]
# 2    [20% Descuento]
# 3    [30% Descuento]
# 4    [40% Descuento]
# 5    [50% Descuento]
# 6              [3x2]
# Name: DESC_PROMOCION, dtype: object

# %%
df_promociones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   COD_PROMOCION   70 non-null     int64
#  1   FECHA_INICIO    70 non-null     datetime64[ns]
#  2   FECHA_FIN       70 non-null     datetime64[ns]
#  3   TIPO_PROMOCION  70 non-null     int64
#  4   DESC_PROMOCION  70 non-null     object
# dtypes: datetime64[ns](2), int64(2), object(1)
# memory usage: 2.9+ KB

# %%
#Guardamos los cambios realizados
df_promociones.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_promociones.pkl')

# %%
# Leer el archivo CSV y cargarlo en un DataFrame
df_promociones = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_promociones.pkl')
print(df_promociones)
# Out:
#     COD_PROMOCION FECHA_INICIO  FECHA_FIN  TIPO_PROMOCION DESC_PROMOCION
# 0               1   2021-01-01 2021-01-08               1  10% Descuento
# 1               2   2021-01-08 2021-01-16               2  20% Descuento
# 2               3   2021-01-01 2021-01-08               3  30% Descuento
# 3               4   2021-01-12 2021-01-14               4  40% Descuento
# 4               5   2021-01-04 2021-01-05               5  50% Descuento
# ..            ...          ...        ...             ...            ...
# 65             66   2022-11-14 2022-11-24               2  20% Descuento
# 66             67   2022-12-03 2022-12-05               3  30% Descuento
# 67             68   2022-12-20 2022-12-23               4  40% Descuento
# 68             69   2022-12-29 2022-12-31               5  50% Descuento
# 69             70   2022-10-14 2022-10-24               6            3x2
#
# [70 rows x 5 columns]

# %% [markdown]
# ## 3.- Dataset Maestro Tiendas

# %% [markdown]
# ### 3.1 Descripcion del Conjunto de Datos
#
#
# 1.   COD_TIENDA: Código de la tienda
#
# 1.   COMUNIDAD: Nombre de la comunidad donde se encuentra la tienda
#
# 2.   CODIGO_POSTAL: Código postal de la tienda
#
# 2.   CALLE: Dirección de la tienda

# %%
df_tiendas = pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/MAESTRO_TIENDAS.csv', sep=',', encoding='latin1')
# Utilizar la función display para mostrar la tabla con columnas
display(df_tiendas.head())
# Out:
#    COD_TIENDA  COMUNIDAD  CODIGO_POSTAL  \
# 0           1   Cambados          36630
# 1           2   Cambrils          43850
# 2           3   Cambrils          43850
# 3           4   Cambrils          43850
# 4           5  Campillos          29320
#
#                                      CALLE
# 0                     Avda.de Vilariño S/N
# 1   Avda. Adelaida, 3 - C/ Cami De La Creu
# 2              C/ Fracesc Perez I Dolç, 30
# 3  C/Josep Llimona - C/ Josep Mª Subirachs
# 4                   Avda. Constitución S/N

# %%
df_tiendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COD_TIENDA     986 non-null    int64
#  1   COMUNIDAD      986 non-null    object
#  2   CODIGO_POSTAL  986 non-null    int64
#  3   CALLE          986 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 30.9+ KB

# %%
df_tiendas.isnull().sum()
# Out:
# COD_TIENDA       0
# COMUNIDAD        0
# CODIGO_POSTAL    0
# CALLE            0
# dtype: int64

# %% [markdown]
# ###3.2 Limpieza y análisis de cada variable en el conjunto de datos

# %% [markdown]
# ####3.2.1 Análisis de columna CODIGO_POSTAL

# %% [markdown]
# #### 3.2.2 Análisis de columna CODIGO_POSTAL

# %% [markdown]
# Verificamos si hay codigos postales en formatos incorrectos

# %%
# Corregimos los códigos postales#
import re

# Expresión regular para verificar el formato de los códigos postales españoles
codigo_postal_regex = r'^[0-5][0-9]{4}$'

# Verificar el formato de los códigos postales en la columna "CODIGO_POSTAL"
codigos_postales_correctos = df_tiendas['CODIGO_POSTAL'].apply(lambda cp: bool(re.match(codigo_postal_regex, str(cp))))

# Mostrar las filas donde los códigos postales no tienen el formato correcto
codigos_postales_incorrectos = df_tiendas[~codigos_postales_correctos]

codigos_postales_incorrectos = codigos_postales_incorrectos[['COMUNIDAD', 'CODIGO_POSTAL']].drop_duplicates()
pd.set_option('display.max_rows', None)
display(codigos_postales_incorrectos)
# Out:
#                      COMUNIDAD  CODIGO_POSTAL
# 6                       Campos           7630
# 7                 Can Pastilla           7610
# 11                   Capdepera           7580
# 14                  Carboneras           4140
# 16                    Cardedeu           8440
# 29                    Castalla           3420
# 31        Castellar Del Valles           8211
# 33               Castelldefels           8860
# 39                     Caudete           2660
# 43       Cerdanyola Del Valles           8290
# 65       Ciutadella De Menorca           7760
# 66                  Cocentaina           3820
# 77       Cornella De Llobregat           8940
# 83                  Crevillent           3330
# 85                    Cubelles           8880
# 90        Cuevas Del Almanzora           4610
# 112        Dehesa De Campoamor           3189
# 114                 Don Benito           6400
# 120                      Dénia           3700
# ...

# %%
corrections = {
    'Can Pastilla': '07610',
    'Capdepera': '07580',
    'Castalla': '03420',
    'Castellar Del Valles': '08211',
    'Castelldefels': '08860',
    'Caudete': '02660',
    'Cerdanyola Del Valles': '08290',
    'Ciutadella De Menorca': '07760',
    'Cornella De Llobregat': '08940',
    'Crevillent': '03330',
    'Cubelles': '08880',
    'Dénia': '03700',
    'El Campello': '03560',
    'El Ejido': '04700',
    'El Prat De Llobregat': '08820',
    'Elx/Elche': '03200',
    'Esparreguera': '08292',
    'Esplugues De Llobregat': '08950',
    'Finestrat': '03509',
    'Garrucha': '04630',
    'Granollers': '08400',
    'Hellin': '02400',
    'Huercal De Almeria': '04230',
    'Huercal-Overa': '04600',
    'Igualada': '08700',
    'Inca': '07300',
    'Javea': '03730',
    'Jerez De Los Caballeros': '06380',
    'L Alfàs Del Pi': '03580',
    'L Hospitalet De Llobregat': '08900',
    'La Mojonera': '04745',
    'La Nucia': '03530',
    'Les Franqueses Del Valles': '08520',
    'Llucmajor': '07620',
    'Adra': '04770',
    'Aguadulce': '04720',
    'Alacant/Alicante': '03001',
    'Albacete': '02001',
    'Alcoi/Alcoy': '03800',
    'Almansa': '02640',
    'Almendralejo': '06200',
    'Almería': '04001',
    'Almoradi': '03160',
    'Altea': '03590',
    'Aranda De Duero': '09400',
    'Arenys De Mar': '08350',
    'Badajoz': '06001',
    'Badalona': '08910',
    'Barbera Del Valles': '08210',
    'Barcelona': '08001',
    'Benidorm': '03500',
    'Benitachell': '03726',
    'Berja': '04760',
    'Burgos': '09001',
    'Calella': '08370',
    'Calpe': '03710',
    'Manacor': '07500',
    'Manresa': '08240',
    'Marratxinet': '07141',
    'Martorell': '08760',
    'Mataró': '08300',
    'Merida': '06800',
    'Miranda De Ebro': '09200',
    'Mojacar': '04638',
    'Molins De Rei': '08750',
    'Mollet Del Valles': '08100',
    'Montcada I Reixac': '08110',
    'Montijo': '06480',
    'Montornes Del Valles': '08170',
    'Muro De Alcoy': '03830',
    'Mutxamel': '03110',
    'Olesa De Montserrat': '08640',
    'Orihuela': '03300',
    'Palau-Solita I Plegamans': '08184',
    'Palma De Mallorca': '07001'
}

for index, row in df_tiendas.iterrows():
    comunidad = row['COMUNIDAD']
    if comunidad in corrections:
        df_tiendas.at[index, 'CODIGO_POSTAL'] = corrections[comunidad]

# %%
# Crear un diccionario con las coincidencias entre comunidad y comunidad autónoma
comunidad_autonoma = {
'Cambrils': 'Cataluña',
'Campo De Criptana': 'Castilla - La Mancha',
'Can Pastilla': 'Islas Baleares',
'Canet D En Berenguer': 'Comunidad Valenciana',
'Capdepera': 'Islas Baleares',
'Carballo': 'Galicia',
'Carcaixent': 'Comunidad Valenciana',
'Carlet': 'Comunidad Valenciana',
'Cartagena': 'Región de Murcia',
'Cartaya': 'Andalucía',
'Castalla': 'Comunidad Valenciana',
'Castellar Del Valles': 'Cataluña',
'Castelldefels':'Cataluña',
'Castello D Empuries': 'Cataluña',
'Catarroja': 'Comunidad Valenciana',
'Caudete': 'Castilla-La Mancha',
'Cee': 'Galicia',
'Cerdanyola Del Valles': 'Cataluña',
'Chauchina': 'Andalucía',
'Chiclana De La Frontera': 'Andalucía',
'Chilches': 'Comunidad Valenciana',
'Churriana': 'Andalucía',
'Ciempozuelos': 'Comunidad de Madrid',
'Cieza': 'Región de Murcia',
'Ciudad Real': 'Castilla-La Mancha',
'Ciutadella De Menorca': 'Islas Baleares',
'Coin': 'Andalucía',
'Collado Villalba': 'Comunidad de Madrid',
'Colmenar Viejo': 'Comunidad de Madrid',
'Conil De La Frontera': 'Andalucía',
'Coria Del Rio': 'Andalucía',
'Cornella De Llobregat': 'Cataluña',
'Cortegana': 'Andalucía',
'Coslada': 'Comunidad de Madrid',
'Crevillent': 'Comunidad Valenciana',
'Cubelles': 'Cataluña',
'Cuenca': 'Castilla-La Mancha',
'Cullera': 'Comunidad Valenciana',
'Cáceres': 'Extremadura',
'Córdoba': 'Andalucía',
'Daganzo De Arriba': 'Comunidad de Madrid',
'De Cartama': 'Andalucía',
'Deltebre': 'Cataluña',
'Dos Hermanas': 'Andalucía',
'Dénia': 'Comunidad Valenciana',
'Ecija': 'Andalucía',
'Ejea De Los Caballeros': 'Aragón',
'El Campello': 'Comunidad Valenciana',
'El Ejido': 'Andalucía',
'El Grao': 'Comunidad Valenciana',
'El Prat De Llobregat': 'Cataluña',
'El Puerto De Santa Maria': 'Andalucía',
'El Puig': 'Comunidad Valenciana',
'El Vendrell': 'Cataluña',
'Elx/Elche': 'Comunidad Valenciana',
'Esparreguera': 'Cataluña',
'Espinardo': 'Región de Murcia',
'Esplugues De Llobregat': 'Cataluña',
'Estella': 'Navarra',
'Estepona': 'Andalucía',
'Fernan-Nuñez': 'Andalucía',
'Figueres': 'Cataluña',
'Finestrat': 'Comunidad Valenciana',
'Foz': 'Galicia',
'Fuengirola': 'Andalucía',
'Fuenlabrada': 'Comunidad de Madrid',
'Fuensalida': 'Castilla-La Mancha',
'Fuente El Saz De Jarama': 'Comunidad de Madrid',
'Galdar': 'Islas Canarias',
'Gandía': 'Comunidad Valenciana',
'Garrucha': 'Andalucía',
'Getafe': 'Comunidad de Madrid',
'Gibraleon': 'Andalucía',
'Gijón': 'Asturias',
'Gines': 'Andalucía',
'Girona': 'Cataluña',
'Granada': 'Andalucía',
'Granollers': 'Cataluña',
'Grao De Gandia': 'Comunidad Valenciana',
'Guadalajara': 'Castilla-La Mancha',
'Guadix': 'Andalucía',
'Guimar': 'Islas Canarias',
'Hellin': 'Castilla-La Mancha',
'Hostalric': 'Cataluña',
'Huelva': 'Andalucía',
'Huercal De Almeria': 'Andalucía',
'Huercal-Overa': 'Andalucía',
'Huesca': 'Aragón',
'Humanes De Madrid': 'Comunidad de Madrid',
'Icod': 'Islas Canarias',
'Igualada': 'Cataluña',
'Illescas': 'Castilla-La Mancha',
'Inca': 'Islas Baleares',
'Ingenio': 'Islas Canarias',
'Jaca': 'Aragón',
'Javea': 'Comunidad Valenciana',
'Jaén': 'Andalucía',
'Jerez De La Frontera': 'Andalucía',
'Jerez De Los Caballeros': 'Extremadura',
'L Alcora': 'Comunidad Valenciana',
'L Alfàs Del Pi': 'Comunidad Valenciana',
'L Eliana': 'Comunidad Valenciana',
'L Escala': 'Cataluña',
'L Hospitalet De Llobregat': 'Cataluña',
'L Olleria': 'Comunidad Valenciana',
'La Almunia De Doña Godina': 'Aragón',
'La Bañeza': 'Castilla y León',
'La Carolina': 'Andalucía',
'La Cañada': 'Comunidad Valenciana',
'La Laguna': 'Islas Canarias',
'La Linea De La Concepcion': 'Andalucía',
'La Mojonera': 'Andalucía',
'La Nucia': 'Comunidad Valenciana',
'La Oliva': 'Islas Canarias',
'Ciudad Real': 'Castilla-La Mancha',
'La Palma Del Condado': 'Andalucía',
'La Rinconada': 'Andalucía',
'La Solana': 'Castilla-La Mancha',
'La Vall D Uixó': 'Comunidad Valenciana',
'La Zubia': 'Andalucía',
'Laredo': 'Cantabria',
'Las Caletillas': 'Canarias',
'Las Gabias': 'Andalucía',
'Las Palmas De Gran Canaria': 'Canarias',
'Las Rozas De Madrid': 'Comunidad de Madrid',
'Lebrija': 'Andalucía',
'Leganés': 'Comunidad de Madrid',
'Lepe': 'Andalucía',
'Les Franqueses Del Valles': 'Cataluña',
'León': 'Castilla y León',
'Linares': 'Andalucía',
'Lleida': 'Cataluña',
'Lliria': 'Comunidad Valenciana',
'Lloret De Mar': 'Cataluña',
'Llucmajor': 'Islas Baleares',
'Logroño': 'La Rioja',
'Lora Del Rio': 'Andalucía',
'Lorca': 'Región de Murcia',
'Los Alcazares': 'Región de Murcia',
'Los Barrios': 'Andalucía',
'Los Realejos': 'Canarias',
'Lucena': 'Andalucía',
'Lugo': 'Galicia',
'Madrid': 'Comunidad de Madrid',
'A Coruña': 'Galicia',
'Abaran': 'Región de Murcia',
'Adeje': 'Canarias',
'Adra': 'Andalucía',
'Aguadulce': 'Andalucía',
'Aguilas': 'Región de Murcia',
'Aguimes': 'Canarias',
'Alacant/Alicante': 'Comunidad Valenciana',
'Alaquàs': 'Comunidad Valenciana',
'Albacete': 'Castilla-La Mancha',
'Albal': 'Comunidad Valenciana',
'Alberic': 'Comunidad Valenciana',
'Alboraya': 'Comunidad Valenciana',
'Alcala De Guadaira': 'Andalucía',
'Alcala Del Rio': 'Andalucía',
'Alcalá De Henares': 'Comunidad de Madrid',
'Alcantarilla': 'Región de Murcia',
'Alcazar De San Juan': 'Castilla-La Mancha',
'Alcañiz': 'Aragón',
'Alcoi/Alcoy': 'Comunidad Valenciana',
'Alcorcón': 'Comunidad de Madrid',
'Aldaia': 'Comunidad Valenciana',
'Alfara Del Patriarca': 'Comunidad Valenciana',
'Algarrobo Costa': 'Andalucía',
'Algeciras': 'Andalucía',
'Algemesi': 'Comunidad Valenciana',
'Alhama De Murcia': 'Región de Murcia',
'Alhaurin De La Torre': 'Andalucía',
'Alhaurin El Grande': 'Andalucía',
'Almagro': 'Castilla-La Mancha',
'Almansa': 'Castilla-La Mancha',
'Almazora': 'Comunidad Valenciana',
'Almendralejo': 'Extremadura',
'Almería': 'Andalucía',
'Almoradi': 'Comunidad Valenciana',
'Almuñecar': 'Andalucía',
'Alovera': 'Castilla-La Mancha',
'Altea': 'Comunidad Valenciana',
'Alzira': 'Comunidad Valenciana',
'Ames': 'Galicia',
'Amposta': 'Cataluña',
'Andujar': 'Andalucía',
'Ansoain': 'Navarra',
'Antequera': 'Andalucía',
'Arahal': 'Andalucía',
'Aranda De Duero': 'Castilla y León',
'Aranjuez': 'Comunidad de Madrid',
'Archena': 'Región de Murcia',
'Arcos De La Frontera': 'Andalucía',
'Arenys De Mar': 'Cataluña',
'Arganda Del Rey': 'Comunidad de Madrid',
'Arnedo': 'La Rioja',
'Arona': 'Canarias',
'Arrecife': 'Canarias',
'Arriondas': 'Asturias',
'Arroyomolinos': 'Comunidad de Madrid',
'Arucas': 'Canarias',
'Astillero': 'Cantabria',
'Atarfe': 'Andalucía',
'Ayamonte': 'Andalucía',
'Azuqueca De Henares': 'Castilla-La Mancha',
'Badajoz': 'Extremadura',
'Badalona': 'Cataluña',
'Baena': 'Andalucía',
'Bailen': 'Andalucía',
'Banyoles': 'Cataluña',
'Barbastro': 'Aragón',
'Barbera Del Valles': 'Cataluña',
'Barcelona': 'Cataluña',
'Bargas': 'Castilla-La Mancha',
'Bejar': 'Castilla y León',
'Bembibre': 'Castilla y León',
'Benahavis': 'Andalucía',
'Benalmadena Costa': 'Andalucía',
'Benetússer': 'Comunidad Valenciana',
'Benicarló': 'Comunidad Valenciana',
'Benicasim': 'Comunidad Valenciana',
'Benidorm': 'Comunidad Valenciana',
'Benifaió': 'Comunidad Valenciana',
'Benimamet': 'Comunidad Valenciana',
'Benitachell': 'Comunidad Valenciana',
'Berja': 'Andalucía',
'Blanes': 'Cataluña',
'Boiro': 'Galicia',
'Bormujos': 'Andalucía',
'Brenes': 'Andalucía',
'Burgos': 'Castilla y León',
'Burguillos De Toledo': 'Castilla-La Mancha',
'Burlada': 'Navarra',
'Burriana': 'Comunidad Valenciana',
'Cabanillas Del Campo': 'Castilla-La Mancha',
'Cabezon De La Sal': 'Cantabria',
'Cabra': 'Andalucía',
'Calahorra': 'La Rioja',
'Calella': 'Cataluña',
'Calonge': 'Cataluña',
'Calpe': 'Comunidad Valenciana',
'Camas': 'Andalucía',
'Mairena Del Alcor': 'Andalucía',
'Mairena Del Aljarafe': 'Andalucía',
'Majadahonda': 'Comunidad de Madrid',
'Malpartida De Caceres': 'Extremadura',
'Manacor': 'Islas Baleares',
'Manilva': 'Andalucía',
'Manises': 'Comunidad Valenciana',
'Manresa': 'Cataluña',
'Manzanares': 'Castilla-La Mancha',
'Marbella': 'Andalucía',
'Marratxinet': 'Islas Baleares',
'Martorell': 'Cataluña',
'Marín': 'Galicia',
'Massamagrell': 'Comunidad Valenciana',
'Mataró': 'Cataluña',
'Mazarron': 'Región de Murcia',
'Meco': 'Comunidad de Madrid',
'Medina Del Campo': 'Castilla y León',
'Mejorada Del Campo': 'Comunidad de Madrid',
'Mengibar': 'Andalucía',
'Merida': 'Extremadura',
'Miajadas': 'Extremadura',
'Mijas': 'Andalucía',
'Miranda De Ebro': 'Castilla y León',
'Mislata': 'Comunidad Valenciana',
'Mojacar': 'Andalucía',
'Molina De Segura': 'Región de Murcia',
'Molins De Rei': 'Cataluña',
'Mollet Del Valles': 'Cataluña',
'Monachil': 'Andalucía',
'Moncofa': 'Comunidad Valenciana',
'Monserrat': 'Comunidad Valenciana',
'Montcada I Reixac': 'Cataluña',
'Montijo': 'Extremadura',
'Montornes Del Valles': 'Cataluña',
'Monzon': 'Aragón',
'Mora D Ebre': 'Cataluña',
'Moron De La Frontera': 'Andalucía',
'Mos': 'Galicia',
'Motril': 'Andalucía',
'Mula': 'Región de Murcia',
'Murcia': 'Región de Murcia',
'Muro De Alcoy': 'Comunidad Valenciana',
'Mutxamel': 'Comunidad Valenciana',
'Málaga': 'Andalucía',
'Móstoles': 'Comunidad de Madrid',
'Naron': 'Galicia',
'Navalmoral De La Mata': 'Extremadura',
'Nerja': 'Andalucía',
'Niguelas': 'Andalucía',
'Noia': 'Galicia',
'Nules': 'Comunidad Valenciana',
'O Seixo Do Chao': 'Galicia',
'Ogijares': 'Andalucía',
'Olesa De Montserrat': 'Cataluña',
'Oliva': 'Comunidad Valenciana',
'Olot': 'Cataluña',
'Olvera': 'Andalucía',
'Onda': 'Comunidad Valenciana',
'Ontinyent': 'Comunidad Valenciana',
'Orihuela': 'Comunidad Valenciana',
'Oropesa': 'Comunidad Valenciana',
'Otura': 'Andalucía',
'Ourense': 'Galicia',
'Oviedo': 'Asturias',
'Palafrugell': 'Cataluña',
'Palau-Solita I Plegamans': 'Cataluña',
'Palencia': 'Castilla y León',
'Palma De Mallorca': 'Islas Baleares',
'Cambados': 'Galicia',
'Campillos': 'Andalucía',
'Campos': 'Islas Baleares',
'Canals': 'Comunidad Valenciana',
'Cantillana': 'Andalucía',
'Caravaca De La Cruz': 'Región de Murcia',
'Carboneras': 'Andalucía',
'Cardedeu': 'Cataluña',
'Carmona': 'Andalucía',
'Cassa De La Selva': 'Cataluña',
'Castell-Platja D Aro': 'Cataluña',
'Castilleja De La Cuesta': 'Andalucía',
'Cazorla': 'Andalucía',
'Cehegin': 'Región de Murcia',
'Cervera': 'Cataluña',
    'Cheste': 'Comunidad Valenciana',
    'Churriana De La Vega': 'Andalucía',
    'Ciudad Rodrigo': 'Castilla y León',
    'Cocentaina': 'Comunidad Valenciana',
    'Colmenarejo': 'Comunidad de Madrid',
    'Coria': 'Extremadura',
    'Corvera': 'Islas Baleares',
    'Cuarte De Huerva': 'Comunidad de Madrid',
    'Cuellar': 'Castilla y León',
    'Cuevas Del Almanzora': 'Andalucía',
    'Cádiz': 'Andalucía',
    'Daimiel': 'Castilla-La Mancha',
    'Dehesa De Campoamor': 'Comunidad Valenciana',
    'Don Benito': 'Extremadura',
    'Eivissa': 'Islas Baleares',
    'El Alamo': 'Comunidad de Madrid',
    'El Casar': 'Castilla-La Mancha',
    'El Escorial': 'Comunidad de Madrid',
    'Elda': 'Comunidad Valenciana',
    'Espartinas': 'Andalucía',
    'Esquinzo': 'Islas Canarias',
    'Estepa': 'Andalucía',
    'Fene': 'Galicia',
    'Ferrol': 'Galicia',
    'Foios': 'Cataluña',
    'Fraga': 'Aragón',
    'Fuente Alamo': 'Castilla-La Mancha',
    'Galapagar': 'Comunidad de Madrid',
    'Granadilla': 'Islas Canarias',
    'Griñon': 'Comunidad de Madrid',
    'Guadalupe': 'Extremadura',
    'Guardamar Del Segura': 'Comunidad Valenciana',
    'Haro': 'La Rioja',
    'Hinojosa Del Duque': 'Andalucía',
    'Huetor Tajar': 'Andalucía',
    'Ibi': 'Comunidad Valenciana',
    'Jumilla': 'Región de Murcia',
    'L Alcúdia': 'Comunidad Valenciana',
    'L Ametlla De Mar': 'Cataluña',
    'L Hospitalet De L Infant': 'Cataluña',
    'La Alberca': 'Castilla y León',
    'La Antigua': 'Extremadura',
    'La Carlota': 'Andalucía',
    'La Cañada De San Urbano': 'Andalucía',
    'La Garriga': 'Cataluña',
    'La Muela': 'Aragón',
    'La Orotava': 'Islas Canarias',
    'La Pobla De Vallbona': 'Comunidad Valenciana',
    'La Roda': 'Castilla-La Mancha',
    'La Union': 'Región de Murcia',
    'Laguna De Duero': 'Castilla y León',
    'Las Cabezas De San Juan': 'Andalucía',
    'Las Torres De Cotillas': 'Región de Murcia',
    'Llinars Del Valles': 'Cataluña',
    'Loja': 'Andalucía',
    'Los Palacios Y Villafranca': 'Andalucía',
    'Abrera': 'Cataluña',
    'Aguilar De La Frontera': 'Andalucía',
    'Albatera': 'Comunidad Valenciana',
    'Albolote': 'Andalucía',
    'Albox': 'Andalucía',
    'Alcala La Real': 'Andalucía',
    'Alcudia': 'Islas Baleares',
    'Alfafar': 'Comunidad Valenciana',
    'Alfaro': 'La Rioja',
    'Alginet': 'Comunidad Valenciana',
    'Aljaraque': 'Andalucía',
    'Almerimar': 'Andalucía',
    'Almonte': 'Andalucía',
    'Alora': 'Andalucía',
    'Andratx': 'Islas Baleares',
    'Aracena': 'Andalucía',
    'Aranguren': 'Navarra',
    'Archidona': 'Andalucía',
    'Armilla': 'Andalucía',
    'Arroyo De La Miel': 'Andalucía',
    'Aspe': 'Comunidad Valenciana',
    'Astorga': 'Castilla y León',
    'Avilés': 'Asturias',
    'Azuaga': 'Extremadura',
    'Badia Del Valles': 'Cataluña',
    'Baeza': 'Andalucía',
    'Balaguer': 'Cataluña',
    'Barbadas': 'Galicia',
    'Barbate': 'Andalucía',
    'Baza': 'Andalucía',
    'Bellreguard Poble': 'Comunidad Valenciana',
    'Benaguasil': 'Comunidad Valenciana',
    'Benavente': 'Castilla y León',
    'Beniajan': 'Región de Murcia',
    'Benijófar': 'Comunidad Valenciana',
    'Benissa': 'Comunidad Valenciana',
    'Berga': 'Cataluña',
    'Betera': 'Comunidad Valenciana',
    'Boadilla Del Monte': 'Comunidad de Madrid',
    'Bollullos Par Del Condado': 'Andalucía',
    'Brunete': 'Comunidad de Madrid',
    'Burjassot': 'Comunidad Valenciana',
    'Buñol': 'Comunidad Valenciana',
    'Cabezo De Torres': 'Región de Murcia',
    'Cabo De Palos': 'Región de Murcia',
    'Calafell': 'Cataluña',
    'Caldes De Montbui': 'Cataluña',
    'Callosa De Segura': 'Comunidad Valenciana',
    'Calvià': 'Islas Baleares',
    'Madridejos': 'Castilla-La Mancha',
    'Malgrat De Mar': 'Cataluña',
    'Mancha Real': 'Andalucía',
    'Manlleu': 'Cataluña',
    'Maracena': 'Andalucía',
    'Marchena': 'Andalucía',
    'Martos': 'Andalucía',
    'Masquefa': 'Cataluña',
    'Massanassa': 'Comunidad Valenciana',
    'Maó': 'Islas Baleares',
    'Medina De Pomar': 'Castilla y León',
    'Medina Sidonia': 'Andalucía',
    'Melenara': 'Islas Canarias',
    'Miguelturra': 'Castilla-La Mancha',
    'Moguer': 'Andalucía',
    'Mollerussa': 'Cataluña',
    'Moncada': 'Comunidad Valenciana',
    'Monforte': 'Galicia',
    'Montblanc': 'Cataluña',
    'Montilla': 'Andalucía',
    'Montoro': 'Andalucía',
    'Monóvar': 'Comunidad Valenciana',
    'Moralzarzal': 'Comunidad de Madrid',
    'Motilla Del Palancar': 'Castilla-La Mancha',
    'Museros': 'Comunidad Valenciana',
    'Navalcarnero': 'Comunidad de Madrid',
    'Nigran': 'Galicia',
    'Nijar': 'Andalucía',
    'Novelda': 'Comunidad Valenciana',
    'O Carballiño': 'Galicia',
    'Ocaña': 'Castilla-La Mancha',
    'Oleiros': 'Galicia',
    'Olivenza': 'Extremadura',
    'Olula Del Rio': 'Andalucía',
    'Ondara': 'Comunidad Valenciana',
    'Orihuela-Costa': 'Comunidad Valenciana',
    'Osuna': 'Andalucía',
    'Paiporta': 'Comunidad Valenciana',
    'Palamos': 'Cataluña'
}

# Agregar la columna COMUNIDAD_AUTONOMA al DataFrame df_tiendas
df_tiendas['COMUNIDAD_AUTONOMA'] = df_tiendas['COMUNIDAD'].map(comunidad_autonoma)

# %%
print(df_tiendas['COMUNIDAD_AUTONOMA'].unique())
# Out:
# ['Galicia' 'Cataluña' 'Andalucía' 'Castilla - La Mancha' 'Islas Baleares'
#  'Comunidad Valenciana' 'Región de Murcia' 'Castilla-La Mancha'
#  'Comunidad de Madrid' 'Castilla y León' 'Extremadura' 'Aragón'
#  'Islas Canarias' 'Navarra' 'Asturias' 'La Rioja' 'Cantabria' 'Canarias']

# %%
#Renombramos para análisis futuras tengan coincidencias con otro Dataframe
df_tiendas.loc[df_tiendas['COMUNIDAD_AUTONOMA'] == 'Navarra', 'COMUNIDAD_AUTONOMA'] = 'Comunidad Foral de Navarra'
df_tiendas.loc[df_tiendas['COMUNIDAD_AUTONOMA'] == 'Asturias', 'COMUNIDAD_AUTONOMA'] = 'Principado de Asturias'
df_tiendas.loc[df_tiendas['COMUNIDAD_AUTONOMA'] == 'Castilla-La Mancha', 'COMUNIDAD_AUTONOMA'] = 'Castilla - La Mancha'
df_tiendas.loc[df_tiendas['COMUNIDAD_AUTONOMA'] == 'Canarias', 'COMUNIDAD_AUTONOMA'] = 'Islas Canarias'
df_tiendas.loc[df_tiendas['COMUNIDAD_AUTONOMA'] == 'Region de Murcia', 'COMUNIDAD_AUTONOMA'] = 'Región de Murcia'

# %%
df_tiendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   COD_TIENDA          986 non-null    int64
#  1   COMUNIDAD           986 non-null    object
#  2   CODIGO_POSTAL       986 non-null    int64
#  3   CALLE               986 non-null    object
#  4   COMUNIDAD_AUTONOMA  986 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 38.6+ KB

# %%
display(df_tiendas.head())
# Out:
#    COD_TIENDA  COMUNIDAD  CODIGO_POSTAL  \
# 0           1   Cambados          36630
# 1           2   Cambrils          43850
# 2           3   Cambrils          43850
# 3           4   Cambrils          43850
# 4           5  Campillos          29320
#
#                                      CALLE COMUNIDAD_AUTONOMA
# 0                     Avda.de Vilariño S/N            Galicia
# 1   Avda. Adelaida, 3 - C/ Cami De La Creu           Cataluña
# 2              C/ Fracesc Perez I Dolç, 30           Cataluña
# 3  C/Josep Llimona - C/ Josep Mª Subirachs           Cataluña
# 4                   Avda. Constitución S/N          Andalucía

# %%
# Guardamos las modificaciones que se han realizado
df_tiendas.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_tiendas.pkl')

# %%
# Leer el archivo CSV y cargarlo en un DataFrame
df_tiendas = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_tiendas.pkl')

# %% [markdown]
# ##4.- Dataset Posicionamiento Productos

# %% [markdown]
# ###4.1 Descripcion del conjunto de datos
#
#
#
# 1.   COD_TIENDA:Código identificador de la tienda
#
# 1.   COD_PRODUCTO:Código del producto
#
# 1.   LEGAL_NAME: Nombre del producto
#
# 1.   ZONA: El lugar de la tienda donde se encuentra el producto
#
# 2.   PASILLO: Número del pasillo donde se encuentra el producto
#
# 2.   ESTANTE: Número del estante donde se encuentra el producto
#
# 2.   SECCION: Número de la seccion donde se encuentra cada producto
#
# 2.   SLUG: Nombre del producto (nombre codificado)

# %%
df_posicionamiento = pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/POSICIONAMIENTO_PRODUCTOS.csv', sep=',', encoding='latin1')
# Mostramos la tabla con columnas
display(df_posicionamiento.head(10))
# Out:
#    COD_TIENDA  COD_PRODUCTO  \
# 0         163         83559
# 1         163         84785
# 2         163         82744
# 3         163         84904
# 4         163         84698
# 5         163         84930
# 6         163         84692
# 7         163         84916
# 8         163         22899
# 9         163          1811
#
#                                           LEGAL_NAME                    ZONA  \
# 0                  barra de  pan cortada multifibras  Panadería y pastelería
# 1  BERLINA CACAO. PRODUCTO DE BOLLERÍA FRITO DESC...  Panadería y pastelería
# 2        Bizcocho recubierto de chocolate sin gluten  Panadería y pastelería
# 3  BIZCOCHO CON AZÚCAR MORENO Y NUECES. PRODUCTO ...  Panadería y pastelería
# 4                               Bizcocho tradicional  Panadería y pastelería
# 5                                  Bizcocho de cacao  Panadería y pastelería
# 6              Bollería prefermentada ultracongelada  Panadería y pastelería
# ...

# %% [markdown]
# ###4.2 Limpieza y análisis de cada variable en el conjunto de datos

# %%
df_posicionamiento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3016174 entries, 0 to 3016173
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   COD_TIENDA    int64
#  1   COD_PRODUCTO  int64
#  2   LEGAL_NAME    object
#  3   ZONA          object
#  4   PASILLO       object
#  5   ESTANTE       object
#  6   SECCION       object
#  7   SLUG          object
# dtypes: int64(2), object(6)
# memory usage: 184.1+ MB

# %%
df_posicionamiento.isnull().sum()
# Out:
# COD_TIENDA      0
# COD_PRODUCTO    0
# LEGAL_NAME      0
# ZONA            0
# PASILLO         0
# ESTANTE         0
# SECCION         0
# SLUG            0
# dtype: int64

# %% [markdown]
# #### 4.2.1 Análisis de la columna LEGAL_NAME

# %% [markdown]
# Se decide eliminar la columna LEGAL_NAME ya que contamos con el nombre del producto en la columna SLUG

# %%
#Eliminamos la columna LEGAL_NAME
df_posicionamiento = df_posicionamiento.drop(['LEGAL_NAME'], axis=1)

# %% [markdown]
# #### 4.2.2 Análisis de columna ZONA

# %% [markdown]
# Se elimina la columna ZONA, ya que cuenta con la misma información que la columna PRODUCT_CATEGORY

# %%
#Zona tiene informacion parecido a PRODUCT_CATEGORY
df_posicionamiento['ZONA'].unique()
# Out:
# array(['Panadería y pastelería', 'Pizzas y platos preparados',
#        'Postres y yogures', 'Zumos', 'Aceite, especias y salsas',
#        'Agua y refrescos', 'Aperitivos', 'Arroz, legumbres y pasta',
#        'Azúcar, caramelos y chocolate', 'Bebé', 'Bodega',
#        'Cacao, café e infusiones', 'Carne', 'Cereales y galletas',
#        'Charcutería y quesos', 'Congelados', 'Conservas, caldos y cremas',
#        'Fitoterapia y parafarmacia', 'Fruta y verdura',
#        'Marisco y pescado'], dtype=object)

# %%
df_posicionamiento = df_posicionamiento.drop('ZONA', axis=1)

# %% [markdown]
# #### 4.2.3 Análisis de variables PASILLO,ESTANTE y SECCION*

# %%
df_posicionamiento['PASILLO'] = df_posicionamiento['PASILLO'].astype(str).str.split().str[-1].astype(int)
df_posicionamiento['ESTANTE'] = df_posicionamiento['ESTANTE'].astype(str).str.split().str[-1].astype(int)
df_posicionamiento['SECCION'] = df_posicionamiento['SECCION'].astype(str).str.split().str[-1].astype(int)

# %%
print(df_posicionamiento['SECCION'].unique())
# Out:
# [ 8  9  1 10  2  3  4  5  6  7]

# %%
print(df_posicionamiento['ESTANTE'].unique())
# Out:
# [1 2 3 4 5]

# %%
print(df_posicionamiento['PASILLO'].unique())
# Out:
# [1 2]

# %%
print(df_posicionamiento.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3016174 entries, 0 to 3016173
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   COD_TIENDA    int64
#  1   COD_PRODUCTO  int64
#  2   PASILLO       int64
#  3   ESTANTE       int64
#  4   SECCION       int64
#  5   SLUG          object
# dtypes: int64(5), object(1)
# memory usage: 138.1+ MB
# None

# %% [markdown]
# ####4.2.4 Análisis de la columna SLUG

# %%
# Reemplazar guiones con espacios en la columna SLUG
df_posicionamiento['SLUG'] = df_posicionamiento['SLUG'].str.replace('-', ' ')

# Mostrar el DataFrame actualizado
print(df_posicionamiento.head())
# Out:
#    COD_TIENDA  COD_PRODUCTO  PASILLO  ESTANTE  SECCION  \
# 0         163         83559        1        1        8
# 1         163         84785        1        1        8
# 2         163         82744        1        1        9
# 3         163         84904        1        1        9
# 4         163         84698        1        1        9
#
#                                               SLUG
# 0            barra pan multifibras cortada paquete
# 1                            berlina cacao paquete
# 2  bizcocho chocolate sin gluten hacendado paquete
# 3        bizcocho con azucar moreno nueces bandeja
# 4           bizcocho tradicional hacendado bandeja

# %%
#Guardamos los cambios realizados
df_posicionamiento.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_posicionamiento.pkl')

# %%
# Leer el archivo CSV y cargarlo en un DataFrame
df_posicionamiento = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_posicionamiento.pkl')

# %% [markdown]
# ##5.- Dataset Promociones Productos

# %% [markdown]
# ###5.1 Descripción del conjunto de datos
#
# 1.   COD_PROMOCION: Código de la promoción
# 2.   COD_PRODUCTO: Código del producto

# %%
df_promoproductos = pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/PROMOCIONES_PRODUCTOS.csv', sep=',', encoding='latin1')
# Utilizar la función display para mostrar la tabla con columnas
display(df_promoproductos.head())
# Out:
#    COD_PROMOCION  COD_PRODUCTO
# 0             22          1423
# 1             46          1564
# 2             13          1680
# 3             58          1680
# 4             25          1699

# %%
df_promoproductos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COD_PROMOCION  5000 non-null   int64
#  1   COD_PRODUCTO   5000 non-null   int64
# dtypes: int64(2)
# memory usage: 78.2 KB

# %%
df_promoproductos.isnull().sum()
# Out:
# COD_PROMOCION    0
# COD_PRODUCTO     0
# dtype: int64

# %%
# Guardamos en pikle
df_promoproductos.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_promoproductos.pkl')

# %%
# Leer el archivo CSV y cargarlo en un DataFrame
df_promoproductos = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_promoproductos.pkl')
print(df_promoproductos.head())

# %% [markdown]
# ## 6.- Dataset Ventas de Tickets del mes de Enero

# %% [markdown]
# ###6.1 Descripción del conjunto de datos
#
#
#
# 1.   COD_TICKET: identificador del ticket de venta, cada compra, este codigo puede ser para otras tiendas y solo es utilizado en 1 día.
#
# 2.   FECHA_VENTA:Fecha en que se realizó la venta
#
# 1.   COD_TIENDA: Código de la tienda
#
# 1.   FORMA_PAGO: Forma de pago (EFECTIVO/TARJETA)
#
# 1.   NUM_LINEA: Número de líneas que aparece en cada ticket de compra, en cada linea sale cuantos productos compraste. Ejm: 3 productos distintos en 3 lineas.
#
# 1.   COD_PRODUCTO: Código del producto
#
# 2.   UNIDADES: Unidades que se vendió
#
# 2.   PRECIO_UNIDAD: Precio unitario
#
# 2.   PRECIO_FINAL:Precio unitario * Unidades
#
# 2.   DESC_PROMOCION: Tipo de descuento de la promoción (10%,20%,30%..etc)

# %%
df_ventas_eneros1= pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/VENTAS_TICKETS_ENERO_S1.csv', sep=';', encoding='latin1')
df_ventas_eneros2= pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/VENTAS_TICKETS_ENERO_S2.csv', sep=';', encoding='latin1')
df_ventas_eneros3= pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/VENTAS_TICKETS_ENERO_S3.csv', sep=';', encoding='latin1')
df_ventas_eneros4= pd.read_csv('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/VENTAS_TICKETS_ENERO_S4.csv', sep=';', encoding='latin1')

# %%
df_ventas_enero = pd.concat([df_ventas_eneros1, df_ventas_eneros2, df_ventas_eneros3, df_ventas_eneros4])

# %%
df_ventas_enero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23971517 entries, 0 to 5874228
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   COD_TICKET      int64
#  1   FECHA_VENTA     object
#  2   COD_TIENDA      int64
#  3   FORMA_PAGO      object
#  4   NUM_LINEA       int64
#  5   COD_PRODUCTO    int64
#  6   UNIDADES        int64
#  7   PRECIO_UNIDAD   object
#  8   PRECIO_FINAL    object
#  9   DESC_PROMOCION  object
# dtypes: int64(5), object(5)
# memory usage: 2.0+ GB

# %% [markdown]
# ###6.2 Limpieza y Análisis de cada variable

# %% [markdown]
# ####6.2.1 Análisis de la variable PRECIO_UNIDAD y PRECIO_FINAL

# %%
# Convertir la columna PRICE a tipo numérico
df_ventas_enero['PRECIO_UNIDAD'] = df_ventas_enero['PRECIO_UNIDAD'].str.replace(',', '.').astype(float)
df_ventas_enero['PRECIO_FINAL'] = df_ventas_enero['PRECIO_FINAL'].str.replace(',', '.').astype(float)

# %% [markdown]
# #### 6.2.2 Análisis de la variable FECHA_VENTA

# %%
# Renombrar la columna 'FECHA_VENTA' a 'FECHA'
df_ventas_enero.rename(columns={'FECHA_VENTA': 'FECHA'}, inplace=True)
#Cambiamos el formato FECHA_VENTA#
df_ventas_enero['FECHA'] = pd.to_datetime(df_ventas_enero['FECHA'], format='%d/%m/%y')

# %%
#Visualizamos los valores nulos
df_ventas_enero.isnull().sum()
# Out:
# COD_TICKET               0
# FECHA                    0
# COD_TIENDA               0
# FORMA_PAGO               0
# NUM_LINEA                0
# COD_PRODUCTO             0
# UNIDADES                 0
# PRECIO_UNIDAD            0
# PRECIO_FINAL             0
# DESC_PROMOCION    22841457
# dtype: int64

# %% [markdown]
# #### 6.2.3Análisis de la variable DESC_PROMOCION

# %%
# Los valors nulos lo llenamos por 'no hay oferta'
df_ventas_enero['DESC_PROMOCION'].fillna("No hay oferta", inplace=True)

# %%
print(df_ventas_enero['DESC_PROMOCION'].unique())
# Out:
# ['No hay oferta' '10% Descuento' '30% Descuento' '50% Descuento'
#  '20% Descuento' '40% Descuento']

# %%
df_ventas_enero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23971517 entries, 0 to 5874228
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   COD_TICKET      int64
#  1   FECHA           datetime64[ns]
#  2   COD_TIENDA      int64
#  3   FORMA_PAGO      object
#  4   NUM_LINEA       int64
#  5   COD_PRODUCTO    int64
#  6   UNIDADES        int64
#  7   PRECIO_UNIDAD   float64
#  8   PRECIO_FINAL    float64
#  9   DESC_PROMOCION  object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 2.0+ GB

# %%
df_ventas_enero.isnull().sum()
# Out:
# COD_TICKET        0
# FECHA             0
# COD_TIENDA        0
# FORMA_PAGO        0
# NUM_LINEA         0
# COD_PRODUCTO      0
# UNIDADES          0
# PRECIO_UNIDAD     0
# PRECIO_FINAL      0
# DESC_PROMOCION    0
# dtype: int64

# %%
#Guardamos los cambios realizados
df_ventas_enero.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_ventas_enero.pkl')

# %%
# Leer el archivo y cargarlo en un DataFrame
df_ventas_enero = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_ventas_enero.pkl')
print(df_ventas_enero.head())
# Out:
#    COD_TICKET      FECHA  COD_TIENDA FORMA_PAGO  NUM_LINEA  COD_PRODUCTO  \
# 0         585 2021-01-02         176   EFECTIVO          1         15087
# 1         585 2021-01-02         176   EFECTIVO          2          8453
# 2         586 2021-01-02         176    TARJETA          1         63521
# 3         586 2021-01-02         176    TARJETA          2         86131
# 4         586 2021-01-02         176    TARJETA          3         83547
#
#    UNIDADES  PRECIO_UNIDAD  PRECIO_FINAL DESC_PROMOCION
# 0         6           1.95         11.70  No hay oferta
# 1         6           1.10          5.94  10% Descuento
# 2         2           3.85          6.93  10% Descuento
# 3         7           9.50         66.50  No hay oferta
# 4         3           1.70          5.10  No hay oferta

# %% [markdown]
# ## 7.- Dataset de Eventos deportivos y feriados en ENERO 2021

# %% [markdown]
# https://blog.versus.es/calendario-de-los-principales-eventos-deportivos-de-enero-de-2021/
# Se encontró información en la página de Apuestas Deportivas que se realiza de manera Online

# %% [markdown]
# Considerando que España es un país con muchos fanáticos del futbol, en Enero del año 2021 se realizó La "SUPERCOPA DE ESPAÑA".
# Nos centraremos en las semifinales y final de la Supercopa de España 2020/2021 que se disputó el 13 de enero y 14 de enero las semifinales y la final el 17 de enero. Los dos finalistas de la Copa del Rey, Athletic y Real Sociedad, tendrán plaza en la Final Four contra Real Madrid y el Barcelona.

# %% [markdown]
# ###7.1 Descripción del conjunto de datos
#
# 1.   FECHA_EVENTO: Fecha del evento
# 2.   EVENTO: Descripción del evento

# %% [markdown]
# ### 7.2 Scrapping de la web

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Hacer la solicitud HTTP GET a la página web
url = 'https://blog.versus.es/calendario-de-los-principales-eventos-deportivos-de-enero-de-2021/'
response = requests.get(url)

# Crear un objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Buscar todos los elementos <li> que contienen los eventos deportivos
event_elements = soup.find_all('li')

# Extraer las fechas y descripciones de los eventos correspondientes a enero
fechas = []
eventos = []
for evento in event_elements:
    # Obtener el texto del elemento
    texto_evento = evento.get_text(strip=True)

    # Verificar si el texto contiene una fecha en formato "X de Enero"
    if ' de Enero' in texto_evento:
        # Separar la fecha y la descripción
        fecha, descripcion = texto_evento.split(':', 1)

        # Agregar la fecha y la descripción a las listas correspondientes
        fechas.append(fecha.strip())
        eventos.append(descripcion.strip())

# Crear un DataFrame con los datos extraídos
data = {'FECHA': fechas, 'EVENTO': eventos}
df_eventos = pd.DataFrame(data)

# Imprimir el DataFrame completo
display(df_eventos)
# Out:
#           FECHA                                             EVENTO
# 0    1 de Enero  NBA en nochevieja y un Manchester United – Ast...
# 1    2 de Enero  El Derbi Sevillano Betis – Sevillay Real Madri...
# 2    3 de Enero  Chelsea – Manchester City y Alavés – Atlético ...
# 3    4 de Enero  7 partidos de NBA y destaca el Warriors – Blazers
# 4    5 de Enero  Semifinales de la EFL Cup (Copa de la Liga ing...
# 5    6 de Enero  Athletic – Barça (jornada 2 aplazada) y Milan ...
# 6    7 de Enero     Warriors – Clippers y Heat – Celtics de la NBA
# 7    8 de Enero                 Borussia – Bayern de la Bundelisga
# 8    9 de Enero  Atleti – Athletic y Sevilla – Real Sociedad en...
# 9   10 de Enero        Clippers – Bulls y 8 partidos más en la NBA
# 10  11 de Enero  Dos partidazos Celtics – Bulls y Rockets – Lakers
# 11  12 de Enero  Atlético de Madrid – Sevilla(partido aplazado ...
# 12  13 de Enero  Primera semifinal Supercopa de España: Real So...
# ...

# %%
#Cambiamos el formato de FECHA_EVENTO

# Crear DataFrame
data = {
    'FECHA': ['1 de Enero', '2 de Enero', '3 de Enero', '4 de Enero', '5 de Enero', '6 de Enero', '7 de Enero', '8 de Enero', '9 de Enero',
                     '10 de Enero', '11 de Enero', '12 de Enero', '13 de Enero', '14 de Enero', '15 de Enero', '16 de Enero', '17 de Enero', '18 de Enero',
                     '19 de Enero', '20 de Enero', '21 de Enero', '22 de Enero', '23 de Enero', '24 de Enero', '25 de Enero', '26 de Enero', '27 de Enero',
                     '28 de Enero', '29 de Enero', '30 de Enero', '31 de Enero'],
     'EVENTO': ['NBA en nochevieja y un Manchester United – Aston Villa', 'El Derbi Sevillano Betis – Sevilla y Real Madrid – Celta',
               'Chelsea – Manchester City y Alavés – Atlético de Madrid', '7 partidos de NBA y destaca el Warriors – Blazers',
               'Semifinales de la EFL Cup (Copa de la Liga inglesa)', 'Athletic – Barça (jornada 2 aplazada) y Milan – Juve',
               'Warriors – Clippers y Heat – Celtics de la NBA', 'Borussia – Bayern de la Bundelisga',
               'Atleti – Athletic y Sevilla – Real Sociedad en LaLiga', 'Clippers – Bulls y 8 partidos más en la NBA',
               'Dos partidazos Celtics – Bulls y Rockets – Lakers', 'Atlético de Madrid – Sevilla (partido aplazado jornada 1)',
               'Primera semifinal Supercopa de España: Real Sociedad – Barça', 'Segunda semifinal Supercopa de España: Real Madrid – Athletic',
               '76ers – Heat, Nuggets – Warriors y 3 partidos más de la NBA', 'Maratón NBA con 11 partidos destacando el Bucks – Mavs',
               'Final Supercopa de España y un Liverpool – Manchester United', '10 partidos de NBA destacando el Thunder – 76ers',
               'La Bundesliga coge protagonismo con el Leverkusen – Dortmund', '1/16 Copa del Rey de los equipos que juegan la Supercopa', 'Otros 11 partidos de NBA con un clásico 76ers – Celtics',
               'El partido más top de la NBA, el Bucks – Lakers', 'Clásico de Bundesliga entre el Schalke 04 y el Bayern',
               'Vuelve LaLiga con un Real Sociedad – Betis y Atleti – Valencia', '5 partidos de NBA que destaca el Bucks – Hawks',
               'Jornada de Premier League y 11 partidos de NBA', 'Solo 3 partidos de NBA donde destacamos el Rockets – Wizards',
               'Partidazo en la Premier League entre el Tottenham y el Liverpool','4 partidos de NBA con un Heat – Clippers con muy buena pinta',
               'Jornada 21 de LaLiga con un Barça – Athletic como mejor partido','Fin de la jornada 21 de LaLiga con un Atleti – Cádiz'],
}

df_eventos = pd.DataFrame(data)

# Definir diccionario de mapeo para los meses
meses_map = {
    'Enero': '01',
}

# Función para convertir el formato de la fecha
def convert_date_format(date_string):
    if pd.isnull(date_string):
        return ''
    parts = date_string.split(' de ')
    day = parts[0]
    month = meses_map[parts[1]]
    year = '2021'
    return f'{day}/{month}/{year}'

# Aplicar la función a la columna 'FECHA_EVENTO'
df_eventos['FECHA'] = df_eventos['FECHA'].apply(convert_date_format)
# Convertir la columna 'FECHA_EVENTO' a tipo datetime
df_eventos['FECHA'] = pd.to_datetime(df_eventos['FECHA'], format='%d/%m/%Y', errors='coerce')

# Imprimir el DataFrame con el nuevo formato de fecha '
print(df_eventos)
# Out:
#         FECHA                                             EVENTO
# 0  2021-01-01  NBA en nochevieja y un Manchester United – Ast...
# 1  2021-01-02  El Derbi Sevillano Betis – Sevilla y Real Madr...
# 2  2021-01-03  Chelsea – Manchester City y Alavés – Atlético ...
# 3  2021-01-04  7 partidos de NBA y destaca el Warriors – Blazers
# 4  2021-01-05  Semifinales de la EFL Cup (Copa de la Liga ing...
# 5  2021-01-06  Athletic – Barça (jornada 2 aplazada) y Milan ...
# 6  2021-01-07     Warriors – Clippers y Heat – Celtics de la NBA
# 7  2021-01-08                 Borussia – Bayern de la Bundelisga
# 8  2021-01-09  Atleti – Athletic y Sevilla – Real Sociedad en...
# 9  2021-01-10        Clippers – Bulls y 8 partidos más en la NBA
# 10 2021-01-11  Dos partidazos Celtics – Bulls y Rockets – Lakers
# 11 2021-01-12  Atlético de Madrid – Sevilla (partido aplazado...
# 12 2021-01-13  Primera semifinal Supercopa de España: Real So...
# ...

# %% [markdown]
# *   2021-01-01  Año Nuevo
#
# *   2021-01-06  Día de Reyes
#
# *   2021-01-13  Primera semifinal Supercopa de España
# *   2021-01-14  Segunda semifinal Supercopa de España
#
#
# *   2021-01-17  Final Supercopa de España

# %%
df_eventos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FECHA   31 non-null     datetime64[ns]
#  1   EVENTO  31 non-null     object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 624.0+ bytes

# %% [markdown]
# Se tiene en cuenta que en Enero hay 2 feriados 1 ENERO: Año nuevo.* y 6 ENERO: Día de Reyes. Añadimos a nuestro dataset.

# %%
# Modificar la descripción del evento del 6 de enero
# Cambia el valor en la columna EVENTO en el índice 5
df_eventos.loc[0, 'EVENTO'] = 'Año nuevo'
df_eventos.loc[5, 'EVENTO'] = 'Día de Reyes'
df_eventos.loc[12, 'EVENTO'] = 'Primera semifinal Supercopa de España'
df_eventos.loc[13, 'EVENTO'] = 'Segunda semifinal Supercopa de España'
df_eventos.loc[16, 'EVENTO'] = 'Final Supercopa de España'

# %%
print(df_eventos.head(20))
# Out:
#         FECHA                                             EVENTO
# 0  2021-01-01                                          Año nuevo
# 1  2021-01-02  El Derbi Sevillano Betis – Sevilla y Real Madr...
# 2  2021-01-03  Chelsea – Manchester City y Alavés – Atlético ...
# 3  2021-01-04  7 partidos de NBA y destaca el Warriors – Blazers
# 4  2021-01-05  Semifinales de la EFL Cup (Copa de la Liga ing...
# 5  2021-01-06                                       Día de Reyes
# 6  2021-01-07     Warriors – Clippers y Heat – Celtics de la NBA
# 7  2021-01-08                 Borussia – Bayern de la Bundelisga
# 8  2021-01-09  Atleti – Athletic y Sevilla – Real Sociedad en...
# 9  2021-01-10        Clippers – Bulls y 8 partidos más en la NBA
# 10 2021-01-11  Dos partidazos Celtics – Bulls y Rockets – Lakers
# 11 2021-01-12  Atlético de Madrid – Sevilla (partido aplazado...
# 12 2021-01-13              Primera semifinal Supercopa de España
# ...

# %%
df_eventos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FECHA   31 non-null     datetime64[ns]
#  1   EVENTO  31 non-null     object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 624.0+ bytes

# %%
#Guardamos los cambios realizados
df_eventos.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_eventos.pkl')

# %%
#lee,ps csv
df_eventos = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/sanitizacion_eventos.pkl')
print(df_eventos.head(20))
# Out:
#         FECHA                                             EVENTO
# 0  2021-01-01                                          Año nuevo
# 1  2021-01-02  El Derbi Sevillano Betis – Sevilla y Real Madr...
# 2  2021-01-03  Chelsea – Manchester City y Alavés – Atlético ...
# 3  2021-01-04  7 partidos de NBA y destaca el Warriors – Blazers
# 4  2021-01-05  Semifinales de la EFL Cup (Copa de la Liga ing...
# 5  2021-01-06                                       Día de Reyes
# 6  2021-01-07     Warriors – Clippers y Heat – Celtics de la NBA
# 7  2021-01-08                 Borussia – Bayern de la Bundelisga
# 8  2021-01-09  Atleti – Athletic y Sevilla – Real Sociedad en...
# 9  2021-01-10        Clippers – Bulls y 8 partidos más en la NBA
# 10 2021-01-11  Dos partidazos Celtics – Bulls y Rockets – Lakers
# 11 2021-01-12  Atlético de Madrid – Sevilla (partido aplazado...
# 12 2021-01-13              Primera semifinal Supercopa de España
# ...

# %% [markdown]
# ##8.- Fusión de los dataframes

# %%
# Realizar la unión de los DataFrames utilizando merge
df_ventas_enero_merge = df_ventas_enero.merge(df_tiendas[['COD_TIENDA', 'COMUNIDAD_AUTONOMA', 'CODIGO_POSTAL']],
                                 on='COD_TIENDA', how='left')

# %%
# Realizar la unión de los DataFrames utilizando merge
df_ventas_enero_merge = df_ventas_enero_merge.merge(df_eventos[['FECHA', 'EVENTO']],
                                        on='FECHA', how='left')

# %%
# Realizar la unión de los DataFrames utilizando merge
df_ventas_enero_merge = df_ventas_enero_merge.merge(df_productos[['COD_PRODUCTO', 'BRAND', 'PRODUCT_CATEGORY','SLUG']],
                                                     on='COD_PRODUCTO', how='left')

# %%
#Guardamos los cambios realizados
df_ventas_enero_merge.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/ventas_sin_posicionamiento.pkl')

# %%
# Leer el archivo y cargarlo en un DataFrame
df_ventas_enero_merge = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/ventas_sin_posicionamiento.pkl')

# %% [markdown]
# ###8.1 Fusión del dataframe con df_posicionamiento

# %%
# Realizar la unión de los DataFrames utilizando merge
#df_ventas_enero_merge = df_ventas_enero_merge.merge(df_posicionamiento[['COD_TIENDA', 'COD_PRODUCTO', 'PASILLO', 'ESTANTE', 'SECCION']],
                                                     #on=['COD_TIENDA', 'COD_PRODUCTO'], how='left')

# %%
# Convertir 'FECHA' a formato datetime
#df_ventas_enero_merge['FECHA'] = pd.to_datetime(df_ventas_enero_merge['FECHA'])

# %%
#Guardamos los cambios realizados
#df_ventas_enero_merge.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/ventas_con_posicionamiento.pkl')

# %%
# Leer el archivo y cargarlo en un DataFrame
#df_ventas_enero_merge = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/ventas_con_posicionamiento.pkl')

# %%
#df_ventas_enero_merge4.isnull().sum()
#Porcentaje de datos con valores nulos = (8,265,856 / 26,798,715) * 100 ≈ 30.8%

# %% [markdown]
# Buscamos las filas de df_ventas_enero_merge4 donde todas las columnas 'ZONA', 'PASILLO', 'ESTANTE' y 'SECCION' tienen valores nulos y combinamos esta información con df_posicionamiento para obtener información sobre las ubicaciones de los productos en las tiendas.

# %%
#df_null_values = df_ventas_enero_merge4[df_ventas_enero_merge4['ZONA'].isnull() & df_ventas_enero_merge4['PASILLO'].isnull() & df_ventas_enero_merge4['ESTANTE'].isnull() & df_ventas_enero_merge4['SECCION'].isnull()]

# %%
#df_comparison = df_null_values.merge(df_posicionamiento, on=['COD_TIENDA', 'COD_PRODUCTO', 'SLUG'], how='left')

# %%
#display(df_comparison)

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.expand_frame_repr', False)
#df_comparison.groupby(['COD_TIENDA', 'COD_PRODUCTO']).nunique()

# %%
# Se verifica que en df_posicionamiento no hay informacion de 'ZONA', 'PASILLO', 'ESTANTE', 'SECCION'
#cod_producto = 1914
#cod_tienda = 1

#filtro = (df_posicionamiento['COD_PRODUCTO'] == cod_producto) & (df_posicionamiento['COD_TIENDA'] == cod_tienda)

#registros = df_posicionamiento.loc[filtro, ['ZONA', 'PASILLO', 'ESTANTE', 'SECCION']]

#if len(registros) > 0:
    #print("Se encontraron registros en las columnas ZONA, PASILLO, ESTANTE y SECCION:")
    #print(registros)
#else:
    #print("No se encontraron registros en las columnas ZONA, PASILLO, ESTANTE y SECCION para el COD_PRODUCTO {} y COD_TIENDA {}.".format(cod_producto, cod_tienda))

# %%
#Para la columna 'ZONA', 'PASILLO', 'ESTANTE' y 'SECCION',utilizamos el método fillna() para reemplazar los valores nulos por 'ZONA 0', 'PASILLO 0', 'SECCION 0':
#df_ventas_enero_merge4['PASILLO'].fillna('0', inplace=True)
#df_ventas_enero_merge4['ESTANTE'].fillna('0', inplace=True)
#df_ventas_enero_merge4['SECCION'].fillna('0', inplace=True)

# %%
#print(df_ventas_enero_merge4['PASILLO'].unique())

# %%
#print(df_ventas_enero_merge4['ESTANTE'].unique())

# %%
#print(df_ventas_enero_merge4['SECCION'].unique())

# %%
#df_ventas_enero_merge4['PASILLO'] = df_ventas_enero_merge4['PASILLO'].astype(int)
#df_ventas_enero_merge4['ESTANTE'] = df_ventas_enero_merge4['ESTANTE'].astype(int)
#df_ventas_enero_merge4['SECCION'] = df_ventas_enero_merge4['SECCION'].astype(int)

# %%
#print(df_ventas_enero_merge4['PASILLO'].unique())

# %%
#print(df_ventas_enero_merge4['ESTANTE'].unique())

# %% [markdown]
# ##9.- Creación de columna DIA_SEMANA

# %%
#Creamos una nueva columna DIA_SEMANA en base a la columna FECHA
df_ventas_enero_merge = df_ventas_enero_merge.assign(DIA_SEMANA=df_ventas_enero_merge['FECHA'].dt.day_name().astype('category'))

# %%
print(df_ventas_enero_merge.head())
# Out:
#    COD_TICKET      FECHA  COD_TIENDA FORMA_PAGO  NUM_LINEA  COD_PRODUCTO  \
# 0         585 2021-01-02         176   EFECTIVO          1         15087
# 1         585 2021-01-02         176   EFECTIVO          2          8453
# 2         586 2021-01-02         176    TARJETA          1         63521
# 3         586 2021-01-02         176    TARJETA          2         86131
# 4         586 2021-01-02         176    TARJETA          3         83547
#
#    UNIDADES  PRECIO_UNIDAD  PRECIO_FINAL DESC_PROMOCION    COMUNIDAD_AUTONOMA  \
# 0         6           1.95         11.70  No hay oferta  Comunidad Valenciana
# 1         6           1.10          5.94  10% Descuento  Comunidad Valenciana
# 2         2           3.85          6.93  10% Descuento  Comunidad Valenciana
# 3         7           9.50         66.50  No hay oferta  Comunidad Valenciana
# 4         3           1.70          5.10  No hay oferta  Comunidad Valenciana
#
# ...

# %% [markdown]
# ##10.- Creación de la columna COD_EVENTO

# %% [markdown]
# Creamos la columna COD_EVENTO, donde le ponemos etiqueta a los eventos mas relevantes en el mes de enero del año 2021. Dónde tendrá las siguientes etiquetas:
#
# *   'sin evento': 0,
# *   'previo al día festivo': 1
# *   'día festivo': 2
#
# **Consideramos día fesitivo las siguientes fechas:**
#
# 2021-01-01 Año Nuevo
#
# 2021-01-06 Día de Reyes
#
# 2021-01-13 Primera semifinal Supercopa de España
#
# 2021-01-14 Segunda semifinal Supercopa de España
#
# 2021-01-17 Final Supercopa de España
#
# Tambien consideramos cómo día festivo los días domingos, que no se abren la tienda.
#
# Días domingos: 2021-01-3,2021-01-10,2021-01-17, 2021-01-24, 2021-01-31.
#
# se asigna el valor de la etiqueta correspondiente a "día festivo" (2)
#
# **Consideramos previo al día festivo:**
# Día sabados: 2021-01-2, 2021-01-9, 2021-01-16, 2021-01-23, 2021-01-30 serán considerados como 'previo al día festivo'(1)
#
# Si el valor de la columna "FECHA" es igual al 2021-01-5 de enero, al 2021-01-12 de enero, y 2021-01-16, se asigna el valor de la etiqueta correspondiente a "previo al día festivo" (1).
#
# **Sin evento:**
#
# En todos los demás casos, se asigna el valor de la etiqueta correspondiente a "sin evento" (0)

# %% [markdown]
# Si el valor de la columna "FECHA" es igual al 5 de enero o al 11 de enero, se asigna el valor de la etiqueta correspondiente a "previo al día festivo" (1). Si el valor de la columna "FECHA" es igual al 6 de enero, 12 de enero, 13 de enero o 17 de enero, se asigna el valor de la etiqueta correspondiente a "día festivo" (2). En todos los demás casos, se asigna el valor de la etiqueta correspondiente a "sin evento" (0).

# %%
# Creamos la columna "COD_EVENTO" basada en la columna "FECHA"
import numpy as np

# Definimos las etiquetas de los eventos
etiquetas_evento = {
    'sin evento': 0,
    'previo al día festivo': 1,
    'día festivo': 2
}
# Definimos las condiciones y las etiquetas correspondientes
condiciones = [
    df_ventas_enero_merge['FECHA'].isin(['2021-01-01', '2021-01-06', '2021-01-13', '2021-01-14', '2021-01-17']),
    (df_ventas_enero_merge['FECHA'].dt.dayofweek == 6) | df_ventas_enero_merge['FECHA'].isin(['2021-01-02', '2021-01-09', '2021-01-16', '2021-01-23', '2021-01-30']),
    (df_ventas_enero_merge['FECHA'].dt.dayofweek == 5),
]

etiquetas = [etiquetas_evento['día festivo'], etiquetas_evento['previo al día festivo'], etiquetas_evento['sin evento']]

# Aplicamos las condiciones y etiquetas con numpy.select
df_ventas_enero_merge['COD_EVENTO'] = np.select(condiciones, etiquetas, default=etiquetas_evento['sin evento'])

# Asegurémonos de que la columna sea de tipo entero
df_ventas_enero_merge['COD_EVENTO'] = df_ventas_enero_merge['COD_EVENTO'].astype(int)

# %%
#Guardamos los cambios realizados
df_ventas_enero_merge.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/ventas_enero_nuevo.pkl')

# %%
# Leer el archivo y cargarlo en un DataFrame
df_ventas_enero_merge = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/ventas_enero_nuevo.pkl')

# %%
# Eliminar las columnas NUM_LINEA y EVENTO
columnas_a_eliminar = ['NUM_LINEA', 'EVENTO']
df_ventas_enero_merge = df_ventas_enero_merge.drop(columnas_a_eliminar, axis=1)

# %% [markdown]
# Por falta de memoria no realizamos merge con el df_promociones, sino creamos la columna y eliminamos desc_promocion

# %% [markdown]
# *   1 [10% Descuento]
# *   2 [20% Descuento]
# *   3 [30% Descuento]
# *   4 [40% Descuento]
# *   5 [50% Descuento]
# *   6 [3x2]

# %%
# Crear la columna TIPO_PROMOCION basada en DESC_PROMOCION
df_ventas_enero_merge['TIPO_PROMOCION'] = df_ventas_enero_merge['DESC_PROMOCION'].map({
    'No hay oferta': 0,
    '10% Descuento': 1,
    '20% Descuento': 2,
    '30% Descuento': 3,
    '40% Descuento': 4,
    '50% Descuento': 5,
    '3x2': 6
})

# Eliminar la columna DESC_PROMOCION
df_ventas_enero_merge = df_ventas_enero_merge.drop('DESC_PROMOCION', axis=1)

# %%
# Visualizar el DataFrame después de la modificación
display(df_ventas_enero_merge.head())
# Out:
#    COD_TICKET      FECHA  COD_TIENDA FORMA_PAGO  COD_PRODUCTO  UNIDADES  \
# 0         585 2021-01-02         176   EFECTIVO         15087         6
# 1         585 2021-01-02         176   EFECTIVO          8453         6
# 2         586 2021-01-02         176    TARJETA         63521         2
# 3         586 2021-01-02         176    TARJETA         86131         7
# 4         586 2021-01-02         176    TARJETA         83547         3
#
#    PRECIO_UNIDAD  PRECIO_FINAL    COMUNIDAD_AUTONOMA  CODIGO_POSTAL  \
# 0           1.95         11.70  Comunidad Valenciana           3509
# 1           1.10          5.94  Comunidad Valenciana           3509
# 2           3.85          6.93  Comunidad Valenciana           3509
# 3           9.50         66.50  Comunidad Valenciana           3509
# 4           1.70          5.10  Comunidad Valenciana           3509
#
#        BRAND            PRODUCT_CATEGORY  \
# 0  Hacendado  Conservas, caldos y cremas
# ...

# %%
df_ventas_enero_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25003813 entries, 0 to 25003812
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   COD_TICKET          int64
#  1   FECHA               datetime64[ns]
#  2   COD_TIENDA          int64
#  3   FORMA_PAGO          object
#  4   COD_PRODUCTO        int64
#  5   UNIDADES            int64
#  6   PRECIO_UNIDAD       float64
#  7   PRECIO_FINAL        float64
#  8   COMUNIDAD_AUTONOMA  object
#  9   CODIGO_POSTAL       int64
#  10  BRAND               object
#  11  PRODUCT_CATEGORY    category
#  12  SLUG                object
#  13  DIA_SEMANA          category
#  14  COD_EVENTO          int64
#  15  TIPO_PROMOCION      int64
# dtypes: category(2), datetime64[ns](1), float64(2), int64(7), object(4)
# memory usage: 2.8+ GB

# %%
#Guardamos los cambios realizados
df_ventas_enero_merge.to_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/ventas_enero_final.pkl')

# %%
#leemos
import pandas as pd
df_ventas_enero_merge = pd.read_pickle('/content/drive/MyDrive/Analítica_de_Datos/TFMDataset_v2/ventas_enero_final.pkl')

# %%
display(df_ventas_enero_merge)
# Out:
#           COD_TICKET      FECHA  COD_TIENDA FORMA_PAGO  COD_PRODUCTO  \
# 0                585 2021-01-02         176   EFECTIVO         15087
# 1                585 2021-01-02         176   EFECTIVO          8453
# 2                586 2021-01-02         176    TARJETA         63521
# 3                586 2021-01-02         176    TARJETA         86131
# 4                586 2021-01-02         176    TARJETA         83547
# ...              ...        ...         ...        ...           ...
# 25003808          52 2021-01-27         365   EFECTIVO         73163
# 25003809          52 2021-01-27         365   EFECTIVO         47152
# 25003810          52 2021-01-27         365   EFECTIVO          3318
# 25003811          52 2021-01-27         365   EFECTIVO         46697
# 25003812          52 2021-01-27         365   EFECTIVO          6321
#
#           UNIDADES  PRECIO_UNIDAD  PRECIO_FINAL    COMUNIDAD_AUTONOMA  \
# ...
